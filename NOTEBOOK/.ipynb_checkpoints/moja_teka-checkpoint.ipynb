# %%
print("mirko")
print("slavko")
# Out:
# mirko
# slavko

# %%
ime_1 = "Pero"
ime_2 = "Marko"
print(ime_1)
print(ime_2)
# Out:
# Pero
# Marko

# %%
# importing required libraries
import matplotlib.pyplot as plt
import matplotlib.image as img
  
# reading the image
testImage = img.imread('g4g.png')
  
# displaying the image
plt.imshow(testImage)

# %%
# %run hello.py
# Out:
# This line will be printed.
# Little prince.

# %%
# %run slika.py

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in d:\python3\lib\site-packages (4.5.5.64)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.14.5 in d:\python3\lib\site-packages (from opencv-python) (1.22.4)

# %%
# %load "hello.py"
print("This line will be printed.")
print("Little prince.")

# %%
# %load "slika.py"
# importing required libraries
import matplotlib.pyplot as plt
import matplotlib.image as img
  
# reading the image
testImage = img.imread('g4g.png')
  
# displaying the image
plt.imshow(testImage)
plt.show()

# %%
from IPython.display import display, HTML
display(HTML('<h1>Hello World</h1>'))
# Out:
# <h1>Hello World</h1>

# %%
from IPython.display import display
display({'text/html': '<h1>Hello World</h1>', 'text/plain': 'Hello World'}, raw=True)
# Out:
# Hello World

# %%
def add(a, b):
    res = a * b
    return res
